# %%
import pandas as pd
import seaborn as sb
import numpy as np  
import json
import pymysql
import sqlalchemy
from sqlalchemy import create_engine

# %%
df= pd.read_csv("rockset-meetup.csv")

# %%
df_json = pd.read_json('rockset.json')

# %%
df=

# %%
df
# Out:
#                                                   _meta  \
# 0     {"kafka":{"topic":"meetup","partition":0,"offs...
# 1     {"kafka":{"topic":"meetup","partition":0,"offs...
# 2     {"kafka":{"topic":"meetup","partition":0,"offs...
# 3     {"kafka":{"topic":"meetup","partition":0,"offs...
# 4     {"kafka":{"topic":"meetup","partition":0,"offs...
# ...                                                 ...
# 2000  {"kafka":{"topic":"meetup","partition":0,"offs...
# 2001  {"kafka":{"topic":"meetup","partition":0,"offs...
# 2002  {"kafka":{"topic":"meetup","partition":0,"offs...
# 2003  {"kafka":{"topic":"meetup","partition":0,"offs...
# 2004  {"kafka":{"topic":"meetup","partition":0,"offs...
#
#                                        _id  \
# 0     09c8d176-c6ec-784a-4ce4-1eea582b3b99
# 1     5dd83017-ca5d-654c-1f93-3e42ecc45184
# 2     258431f4-63c2-807a-7b8d-f4d9c2d3185e
# 3     be792538-1385-ec42-8917-ae31a1d55b5b
# 4     17c67ae4-f2a0-f58a-d84b-2196fdc243d6
# ...

# %%
df = df.drop(columns=["_meta", "_id", "Unnamed: 12"])

# %%
df
# Out:
#                                                   group  \
# 0     {"group_lat":-37.81,"group_name":"Northside Ex...
# 1     {"group_lat":-37.81,"group_name":"Product Talk...
# 2     {"group_lat":40.76,"group_name":"The Thalesian...
# 3     {"group_lat":46.52,"group_name":"Comment créer...
# 4     {"group_lat":52.52,"group_name":"French Berlin...
# ...                                                 ...
# 2000  {"group_lat":21.29,"group_name":"Oahu Long Ter...
# 2001  {"group_lat":47.38,"group_name":"ClickUp Geeks...
# 2002  {"group_lat":-33.87,"group_name":"Sydney UC - ...
# 2003  {"group_lat":40.42,"group_name":"Partidas de r...
# 2004  {"group_lat":48.14,"group_name":"Agile Heroes ...
#
#                                                   event response  \
# 0     {"event_name":"Online Trivia via Zoom ","time"...       no
# 1     {"event_name":"AMA with Agnes Misiurny","time"...      yes
# 2     {"event_name":"Webinar: Bilal Hafeez (Macro Hi...      yes
# ...

# %% [markdown]
# # Cleaning and Arranging Group

# %%
df_1= pd.concat([df, df["group"].str.split(',', expand=True)], axis=1)

# %%
df_1
# Out:
#                                                   group  \
# 0     {"group_lat":-37.81,"group_name":"Northside Ex...
# 1     {"group_lat":-37.81,"group_name":"Product Talk...
# 2     {"group_lat":40.76,"group_name":"The Thalesian...
# 3     {"group_lat":46.52,"group_name":"Comment créer...
# 4     {"group_lat":52.52,"group_name":"French Berlin...
# ...                                                 ...
# 2000  {"group_lat":21.29,"group_name":"Oahu Long Ter...
# 2001  {"group_lat":47.38,"group_name":"ClickUp Geeks...
# 2002  {"group_lat":-33.87,"group_name":"Sydney UC - ...
# 2003  {"group_lat":40.42,"group_name":"Partidas de r...
# 2004  {"group_lat":48.14,"group_name":"Agile Heroes ...
#
#                                                   event response  \
# 0     {"event_name":"Online Trivia via Zoom ","time"...       no
# 1     {"event_name":"AMA with Agnes Misiurny","time"...      yes
# 2     {"event_name":"Webinar: Bilal Hafeez (Macro Hi...      yes
# ...

# %%
df_1 = df_1.dropna(axis=1)

# %%
df_1
# Out:
#                                                   group  \
# 0     {"group_lat":-37.81,"group_name":"Northside Ex...
# 1     {"group_lat":-37.81,"group_name":"Product Talk...
# 2     {"group_lat":40.76,"group_name":"The Thalesian...
# 3     {"group_lat":46.52,"group_name":"Comment créer...
# 4     {"group_lat":52.52,"group_name":"French Berlin...
# ...                                                 ...
# 2000  {"group_lat":21.29,"group_name":"Oahu Long Ter...
# 2001  {"group_lat":47.38,"group_name":"ClickUp Geeks...
# 2002  {"group_lat":-33.87,"group_name":"Sydney UC - ...
# 2003  {"group_lat":40.42,"group_name":"Partidas de r...
# 2004  {"group_lat":48.14,"group_name":"Agile Heroes ...
#
#                                                   event response  \
# 0     {"event_name":"Online Trivia via Zoom ","time"...       no
# 1     {"event_name":"AMA with Agnes Misiurny","time"...      yes
# 2     {"event_name":"Webinar: Bilal Hafeez (Macro Hi...      yes
# ...

# %%
df_1.drop(columns= 0)
# Out:
#                                                   group  \
# 0     {"group_lat":-37.81,"group_name":"Northside Ex...
# 1     {"group_lat":-37.81,"group_name":"Product Talk...
# 2     {"group_lat":40.76,"group_name":"The Thalesian...
# 3     {"group_lat":46.52,"group_name":"Comment créer...
# 4     {"group_lat":52.52,"group_name":"French Berlin...
# ...                                                 ...
# 2000  {"group_lat":21.29,"group_name":"Oahu Long Ter...
# 2001  {"group_lat":47.38,"group_name":"ClickUp Geeks...
# 2002  {"group_lat":-33.87,"group_name":"Sydney UC - ...
# 2003  {"group_lat":40.42,"group_name":"Partidas de r...
# 2004  {"group_lat":48.14,"group_name":"Agile Heroes ...
#
#                                                   event response  \
# 0     {"event_name":"Online Trivia via Zoom ","time"...       no
# 1     {"event_name":"AMA with Agnes Misiurny","time"...      yes
# 2     {"event_name":"Webinar: Bilal Hafeez (Macro Hi...      yes
# ...

# %%
df_1= df_1.drop(columns= ["group", 0, 6, 8])

# %%
df_1= df_1.drop(columns= 7)

# %% [markdown]
# ## groupname

# %%
df_1 = df_1.rename(columns = {1:'Group_name'})

# %%
df_1["Group_name"] = df_1["Group_name"].replace({'"group_name":"':''}, regex = True)

# %%
df_1["Group_name"] = df_1["Group_name"].replace({'"':''}, regex = True)

# %%
df_1
# Out:
#                                                   event response  \
# 0     {"event_name":"Online Trivia via Zoom ","time"...       no
# 1     {"event_name":"AMA with Agnes Misiurny","time"...      yes
# 2     {"event_name":"Webinar: Bilal Hafeez (Macro Hi...      yes
# 3     {"event_name":"L’amour du risque, oser malgré ...      yes
# 4     {"event_name":"Parlons français ! Café philoso...      yes
# ...                                                 ...      ...
# 2000  {"event_name":"Dinner at Mexico Restaurant","t...      yes
# 2001  {"event_name":"ClickUp «Docs» als Informations...      yes
# 2002  {"event_name":"Sydney UC August 2021 Meetup","...      yes
# 2003  {"event_name":"Aprende a Jugar a Fallout | One...      yes
# 2004  {"event_name":"„Facilitator - Funktionen und h...       no
#
#                       _event_time     rsvp_id  \
# 0     2021-08-19T07:42:48.406000Z  1883963961
# 1     2021-08-19T07:42:48.406000Z  1884076700
# ...

# %% [markdown]
# ## group id

# %%
df_1 = df_1.rename(columns = {2:'Group_ID'})

# %%
df_1["Group_ID"] = df_1["Group_ID"].replace({'"group_id":':''}, regex = True)

# %%
df_1.head()
# Out:
#                                                event response  \
# 0  {"event_name":"Online Trivia via Zoom ","time"...       no
# 1  {"event_name":"AMA with Agnes Misiurny","time"...      yes
# 2  {"event_name":"Webinar: Bilal Hafeez (Macro Hi...      yes
# 3  {"event_name":"L’amour du risque, oser malgré ...      yes
# 4  {"event_name":"Parlons français ! Café philoso...      yes
#
#                    _event_time     rsvp_id  \
# 0  2021-08-19T07:42:48.406000Z  1883963961
# 1  2021-08-19T07:42:48.406000Z  1884076700
# 2  2021-08-19T07:42:48.406000Z  1884076873
# 3  2021-08-19T07:42:48.406000Z  1884076719
# 4  2021-08-19T07:42:48.406000Z  1884076769
#
#                                               member visibility  guests  \
# 0  {"member_id":286812947,"photo":"https://secure...     public       0
# 1  {"member_id":41344852,"photo":"https://secure....     public       0
# 2  {"member_id":305576915,"member_name":"Martin R...     public       0
# ...

# %% [markdown]
# ## Group_urlname

# %%
df_1 = df_1.rename(columns = {3:'Group_URLname'})

# %%
df_1["Group_URLname"] = df_1["Group_URLname"].replace({'"group_urlname":"':''}, regex = True)

# %%
df_1["Group_URLname"] = df_1["Group_URLname"].replace({'"':''}, regex = True)

# %%
df_1.head(2)
# Out:
#                                                event response  \
# 0  {"event_name":"Online Trivia via Zoom ","time"...       no
# 1  {"event_name":"AMA with Agnes Misiurny","time"...      yes
#
#                    _event_time     rsvp_id  \
# 0  2021-08-19T07:42:48.406000Z  1883963961
# 1  2021-08-19T07:42:48.406000Z  1884076700
#
#                                               member visibility  guests  \
# 0  {"member_id":286812947,"photo":"https://secure...     public       0
# 1  {"member_id":41344852,"photo":"https://secure....     public       0
#
#            mtime                                         Group_name  Group_ID  \
# 0  1629358881316  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765
# 1  1629358701725                            Product Talks Melbourne  33585358
#
#              Group_URLname                     4  \
# 0      Northside-Explorers  "group_country":"au"
# 1  Product-Talks-Melbourne  "group_country":"au"
#
# ...

# %%
df_1 = df_1.drop(columns= "Group_URLname")

# %% [markdown]
# ## group_country

# %%
df_1 = df_1.rename(columns = {4:'Group_Country'})

# %%
df_1["Group_Country"] = df_1["Group_Country"].replace({'"group_country":':''}, regex = True)

# %%
df_1["Group_Country"] = df_1["Group_Country"].replace({'"':''}, regex = True)

# %%
df_1.head(2)
# Out:
#                                                event response  \
# 0  {"event_name":"Online Trivia via Zoom ","time"...       no
# 1  {"event_name":"AMA with Agnes Misiurny","time"...      yes
#
#                    _event_time     rsvp_id  \
# 0  2021-08-19T07:42:48.406000Z  1883963961
# 1  2021-08-19T07:42:48.406000Z  1884076700
#
#                                               member visibility  guests  \
# 0  {"member_id":286812947,"photo":"https://secure...     public       0
# 1  {"member_id":41344852,"photo":"https://secure....     public       0
#
#            mtime                                         Group_name  Group_ID  \
# 0  1629358881316  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765
# 1  1629358701725                            Product Talks Melbourne  33585358
#
#   Group_Country                                           5
# 0            au        "group_topics":[{"topic_name":"Wine"
# 1            au  "group_topics":[{"topic_name":"Innovation"

# %% [markdown]
# ## topic name

# %%
df_1 = df_1.rename(columns = {5:'Topic'})

# %%
df_1["Topic"] = df_1["Topic"].replace({'"group_topics"':''}, regex = True)

# %%
df_1.head()
# Out:
#                                                event response  \
# 0  {"event_name":"Online Trivia via Zoom ","time"...       no
# 1  {"event_name":"AMA with Agnes Misiurny","time"...      yes
# 2  {"event_name":"Webinar: Bilal Hafeez (Macro Hi...      yes
# 3  {"event_name":"L’amour du risque, oser malgré ...      yes
# 4  {"event_name":"Parlons français ! Café philoso...      yes
#
#                    _event_time     rsvp_id  \
# 0  2021-08-19T07:42:48.406000Z  1883963961
# 1  2021-08-19T07:42:48.406000Z  1884076700
# 2  2021-08-19T07:42:48.406000Z  1884076873
# 3  2021-08-19T07:42:48.406000Z  1884076719
# 4  2021-08-19T07:42:48.406000Z  1884076769
#
#                                               member visibility  guests  \
# 0  {"member_id":286812947,"photo":"https://secure...     public       0
# 1  {"member_id":41344852,"photo":"https://secure....     public       0
# 2  {"member_id":305576915,"member_name":"Martin R...     public       0
# ...

# %%
df_1["Topic"] = df_1["Topic"].replace({'topic_name':''}, regex = True)

# %%
df_1["Topic"] = df_1["Topic"].replace({'{"":"':''}, regex = True)

# %%
df_1["Topic"] = df_1["Topic"].replace({':':''}, regex = True)

# %%
df_1["Topic"] = df_1["Topic"].replace({'"':''}, regex = True)

# %%
df_1.head(2)
# Out:
#                                                event response  \
# 0  {"event_name":"Online Trivia via Zoom ","time"...       no
# 1  {"event_name":"AMA with Agnes Misiurny","time"...      yes
#
#                    _event_time     rsvp_id  \
# 0  2021-08-19T07:42:48.406000Z  1883963961
# 1  2021-08-19T07:42:48.406000Z  1884076700
#
#                                               member visibility  guests  \
# 0  {"member_id":286812947,"photo":"https://secure...     public       0
# 1  {"member_id":41344852,"photo":"https://secure....     public       0
#
#            mtime                                         Group_name  Group_ID  \
# 0  1629358881316  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765
# 1  1629358701725                            Product Talks Melbourne  33585358
#
#   Group_Country        Topic
# 0            au        [Wine
# 1            au  [Innovation

# %% [markdown]
# # Event

# %%
df_1.head(1)
# Out:
#                                                event response  \
# 0  {"event_name":"Online Trivia via Zoom ","time"...       no
#
#                    _event_time     rsvp_id  \
# 0  2021-08-19T07:42:48.406000Z  1883963961
#
#                                               member visibility  guests  \
# 0  {"member_id":286812947,"photo":"https://secure...     public       0
#
#            mtime                                         Group_name  Group_ID  \
# 0  1629358881316  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765
#
#   Group_Country  Topic
# 0            au  [Wine

# %%
df_2= pd.concat([df_1, df_1["event"].str.split(',', expand=True)], axis=1)

# %%
df_2.head(2)
# Out:
#                                                event response  \
# 0  {"event_name":"Online Trivia via Zoom ","time"...       no
# 1  {"event_name":"AMA with Agnes Misiurny","time"...      yes
#
#                    _event_time     rsvp_id  \
# 0  2021-08-19T07:42:48.406000Z  1883963961
# 1  2021-08-19T07:42:48.406000Z  1884076700
#
#                                               member visibility  guests  \
# 0  {"member_id":286812947,"photo":"https://secure...     public       0
# 1  {"member_id":41344852,"photo":"https://secure....     public       0
#
#            mtime                                         Group_name  Group_ID  \
# 0  1629358881316  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765
# 1  1629358701725                            Product Talks Melbourne  33585358
#
#   Group_Country        Topic                                        0  \
# 0            au        [Wine  {"event_name":"Online Trivia via Zoom "
# ...

# %%
df_2 = df_2.dropna(axis=1)

# %%
df_2.head(2)
# Out:
#                                                event response  \
# 0  {"event_name":"Online Trivia via Zoom ","time"...       no
# 1  {"event_name":"AMA with Agnes Misiurny","time"...      yes
#
#                    _event_time     rsvp_id  \
# 0  2021-08-19T07:42:48.406000Z  1883963961
# 1  2021-08-19T07:42:48.406000Z  1884076700
#
#                                               member visibility  guests  \
# 0  {"member_id":286812947,"photo":"https://secure...     public       0
# 1  {"member_id":41344852,"photo":"https://secure....     public       0
#
#            mtime                                         Group_name  Group_ID  \
# 0  1629358881316  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765
# 1  1629358701725                            Product Talks Melbourne  33585358
#
#   Group_Country        Topic                                        0  \
# 0            au        [Wine  {"event_name":"Online Trivia via Zoom "
# ...

# %%
df_2 = df_2.drop(columns= 1)

# %%
df_2= df_2.drop(columns= "event")

# %% [markdown]
# ## event name

# %%
df_2 = df_2.rename(columns = {0:'event_name'})

# %%
df_2["event_name"] = df_2["event_name"].replace({'{"event_name":"':''}, regex = True)

# %%
df_2["event_name"] = df_2["event_name"].replace({'"':''}, regex = True)

# %%
df_2.head(2)
# Out:
#   response                  _event_time     rsvp_id  \
# 0       no  2021-08-19T07:42:48.406000Z  1883963961
# 1      yes  2021-08-19T07:42:48.406000Z  1884076700
#
#                                               member visibility  guests  \
# 0  {"member_id":286812947,"photo":"https://secure...     public       0
# 1  {"member_id":41344852,"photo":"https://secure....     public       0
#
#            mtime                                         Group_name  Group_ID  \
# 0  1629358881316  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765
# 1  1629358701725                            Product Talks Melbourne  33585358
#
#   Group_Country        Topic               event_name  \
# 0            au        [Wine  Online Trivia via Zoom
# 1            au  [Innovation  AMA with Agnes Misiurny
#
#                                                    2
# 0  "event_url":"https://www.meetup.com/Northside-...
# 1  "event_url":"https://www.meetup.com/Product-Ta...

# %% [markdown]
# ## event URL

# %%
df_2 = df_2.rename(columns = {2:'event_url'})

# %%
df_2["event_url"] = df_2["event_url"].replace({'"event_url":"':''}, regex = True)

# %%
df_2["event_name"] = df_2["event_name"].replace({'"':''}, regex = True)

# %%
df_2.head(2)
# Out:
#   response                  _event_time     rsvp_id  \
# 0       no  2021-08-19T07:42:48.406000Z  1883963961
# 1      yes  2021-08-19T07:42:48.406000Z  1884076700
#
#                                               member visibility  guests  \
# 0  {"member_id":286812947,"photo":"https://secure...     public       0
# 1  {"member_id":41344852,"photo":"https://secure....     public       0
#
#            mtime                                         Group_name  Group_ID  \
# 0  1629358881316  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765
# 1  1629358701725                            Product Talks Melbourne  33585358
#
#   Group_Country        Topic               event_name  \
# 0            au        [Wine  Online Trivia via Zoom
# 1            au  [Innovation  AMA with Agnes Misiurny
#
#                                            event_url
# 0  https://www.meetup.com/Northside-Explorers/eve...
# 1  https://www.meetup.com/Product-Talks-Melbourne...

# %% [markdown]
# # Member

# %%
df_2.head(1)
# Out:
#   response                  _event_time     rsvp_id  \
# 0       no  2021-08-19T07:42:48.406000Z  1883963961
#
#                                               member visibility  guests  \
# 0  {"member_id":286812947,"photo":"https://secure...     public       0
#
#            mtime                                         Group_name  Group_ID  \
# 0  1629358881316  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765
#
#   Group_Country  Topic               event_name  \
# 0            au  [Wine  Online Trivia via Zoom
#
#                                            event_url
# 0  https://www.meetup.com/Northside-Explorers/eve...

# %%
df_3= pd.concat([df_2, df_2["member"].str.split(',', expand=True)], axis=1)

# %%
df_3.head(2)
# Out:
#   response                  _event_time     rsvp_id  \
# 0       no  2021-08-19T07:42:48.406000Z  1883963961
# 1      yes  2021-08-19T07:42:48.406000Z  1884076700
#
#                                               member visibility  guests  \
# 0  {"member_id":286812947,"photo":"https://secure...     public       0
# 1  {"member_id":41344852,"photo":"https://secure....     public       0
#
#            mtime                                         Group_name  Group_ID  \
# 0  1629358881316  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765
# 1  1629358701725                            Product Talks Melbourne  33585358
#
#   Group_Country        Topic               event_name  \
# 0            au        [Wine  Online Trivia via Zoom
# 1            au  [Innovation  AMA with Agnes Misiurny
#
#                                            event_url                       0  \
# 0  https://www.meetup.com/Northside-Explorers/eve...  {"member_id":286812947
# ...

# %%
df_3 = df_3.drop(columns= ["member", 3, 4])

# %%
df_3.head(2)
# Out:
#   response                  _event_time     rsvp_id visibility  guests  \
# 0       no  2021-08-19T07:42:48.406000Z  1883963961     public       0
# 1      yes  2021-08-19T07:42:48.406000Z  1884076700     public       0
#
#            mtime                                         Group_name  Group_ID  \
# 0  1629358881316  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765
# 1  1629358701725                            Product Talks Melbourne  33585358
#
#   Group_Country        Topic               event_name  \
# 0            au        [Wine  Online Trivia via Zoom
# 1            au  [Innovation  AMA with Agnes Misiurny
#
#                                            event_url                       0  \
# 0  https://www.meetup.com/Northside-Explorers/eve...  {"member_id":286812947
# 1  https://www.meetup.com/Product-Talks-Melbourne...   {"member_id":41344852
#
#                                                    1  \
# 0  "photo":"https://secure.meetupstatic.com/photo...
# ...

# %% [markdown]
# ## member_id

# %%
df_3 = df_3.rename(columns = {0:'member_id'})

# %%
df_3["member_id"] = df_3["member_id"].replace({'{"member_id":':''}, regex = True)

# %%
df_3.head(2)
# Out:
#   response                  _event_time     rsvp_id visibility  guests  \
# 0       no  2021-08-19T07:42:48.406000Z  1883963961     public       0
# 1      yes  2021-08-19T07:42:48.406000Z  1884076700     public       0
#
#            mtime                                         Group_name  Group_ID  \
# 0  1629358881316  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765
# 1  1629358701725                            Product Talks Melbourne  33585358
#
#   Group_Country        Topic               event_name  \
# 0            au        [Wine  Online Trivia via Zoom
# 1            au  [Innovation  AMA with Agnes Misiurny
#
#                                            event_url  member_id  \
# 0  https://www.meetup.com/Northside-Explorers/eve...  286812947
# 1  https://www.meetup.com/Product-Talks-Melbourne...   41344852
#
#                                                    1  \
# 0  "photo":"https://secure.meetupstatic.com/photo...
# ...

# %% [markdown]
# ## photo

# %%
df_3 = df_3.rename(columns = {1:'member_photo'})

# %%
df_3["member_photo"] = df_3["member_photo"].replace({'"photo":"':''}, regex = True)

# %%
df_3.head(2)
# Out:
#   response                  _event_time     rsvp_id visibility  guests  \
# 0       no  2021-08-19T07:42:48.406000Z  1883963961     public       0
# 1      yes  2021-08-19T07:42:48.406000Z  1884076700     public       0
#
#            mtime                                         Group_name  Group_ID  \
# 0  1629358881316  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765
# 1  1629358701725                            Product Talks Melbourne  33585358
#
#   Group_Country        Topic               event_name  \
# 0            au        [Wine  Online Trivia via Zoom
# 1            au  [Innovation  AMA with Agnes Misiurny
#
#                                            event_url  member_id  \
# 0  https://www.meetup.com/Northside-Explorers/eve...  286812947
# 1  https://www.meetup.com/Product-Talks-Melbourne...   41344852
#
#                                         member_photo  \
# 0  https://secure.meetupstatic.com/photos/member/...
# ...

# %% [markdown]
# ## member name

# %%
df_3 = df_3.rename(columns = {2:'member_name'})

# %%
df_3["member_name"] = df_3["member_name"].replace({'"member_name":"':''}, regex = True)

# %%
df_3["member_name"] = df_3["member_name"].replace({'"}':''}, regex = True)

# %%
df_3.head()
# Out:
#   response                  _event_time     rsvp_id visibility  guests  \
# 0       no  2021-08-19T07:42:48.406000Z  1883963961     public       0
# 1      yes  2021-08-19T07:42:48.406000Z  1884076700     public       0
# 2      yes  2021-08-19T07:42:48.406000Z  1884076873     public       0
# 3      yes  2021-08-19T07:42:48.406000Z  1884076719     public       0
# 4      yes  2021-08-19T07:42:48.406000Z  1884076769     public       0
#
#            mtime                                         Group_name  Group_ID  \
# 0  1629358881316  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765
# 1  1629358701725                            Product Talks Melbourne  33585358
# 2  1629358933752                                     The Thalesians   1435784
# 3  1629358731000                 Comment créer son entreprise - IFJ  30484029
# 4  1629358799000                                      French Berlin  27281862
#
#   Group_Country             Topic  \
# ...

# %% [markdown]
# # event time

# %%
df_3= pd.concat([df_3, df_3["_event_time"].str.split('T', expand=True)], axis=1)

# %%
df_3.head()
# Out:
#   response                  _event_time     rsvp_id visibility  guests  \
# 0       no  2021-08-19T07:42:48.406000Z  1883963961     public       0
# 1      yes  2021-08-19T07:42:48.406000Z  1884076700     public       0
# 2      yes  2021-08-19T07:42:48.406000Z  1884076873     public       0
# 3      yes  2021-08-19T07:42:48.406000Z  1884076719     public       0
# 4      yes  2021-08-19T07:42:48.406000Z  1884076769     public       0
#
#            mtime                                         Group_name  Group_ID  \
# 0  1629358881316  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765
# 1  1629358701725                            Product Talks Melbourne  33585358
# 2  1629358933752                                     The Thalesians   1435784
# 3  1629358731000                 Comment créer son entreprise - IFJ  30484029
# 4  1629358799000                                      French Berlin  27281862
#
#   Group_Country             Topic  \
# ...

# %% [markdown]
# ## event date

# %%
df_3.head(2)
# Out:
#   response                  _event_time     rsvp_id visibility  guests  \
# 0       no  2021-08-19T07:42:48.406000Z  1883963961     public       0
# 1      yes  2021-08-19T07:42:48.406000Z  1884076700     public       0
#
#            mtime                                         Group_name  Group_ID  \
# 0  1629358881316  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765
# 1  1629358701725                            Product Talks Melbourne  33585358
#
#   Group_Country        Topic               event_name  \
# 0            au        [Wine  Online Trivia via Zoom
# 1            au  [Innovation  AMA with Agnes Misiurny
#
#                                            event_url  member_id  \
# 0  https://www.meetup.com/Northside-Explorers/eve...  286812947
# 1  https://www.meetup.com/Product-Talks-Melbourne...   41344852
#
#                                         member_photo  member_name           0  \
# ...

# %%
df_3 = df_3.rename(columns = {0:'event_date'})

# %% [markdown]
# ## event time

# %%
df_3 = df_3.rename(columns = {1:'event_time'})

# %%
df_3["event_time"] = df_3["event_time"].replace({'.406000Z':''}, regex = True)

# %%
df_3.head(2)
# Out:
#   response                  _event_time     rsvp_id visibility  guests  \
# 0       no  2021-08-19T07:42:48.406000Z  1883963961     public       0
# 1      yes  2021-08-19T07:42:48.406000Z  1884076700     public       0
#
#            mtime                                         Group_name  Group_ID  \
# 0  1629358881316  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765
# 1  1629358701725                            Product Talks Melbourne  33585358
#
#   Group_Country        Topic               event_name  \
# 0            au        [Wine  Online Trivia via Zoom
# 1            au  [Innovation  AMA with Agnes Misiurny
#
#                                            event_url  member_id  \
# 0  https://www.meetup.com/Northside-Explorers/eve...  286812947
# 1  https://www.meetup.com/Product-Talks-Melbourne...   41344852
#
#                                         member_photo  member_name  event_date  \
# ...

# %%
df_3 = df_3.drop(columns= ["mtime"])

# %%
df_3.head()
# Out:
#   response     rsvp_id visibility  guests  \
# 0       no  1883963961     public       0
# 1      yes  1884076700     public       0
# 2      yes  1884076873     public       0
# 3      yes  1884076719     public       0
# 4      yes  1884076769     public       0
#
#                                           Group_name  Group_ID Group_Country  \
# 0  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765            au
# 1                            Product Talks Melbourne  33585358            au
# 2                                     The Thalesians   1435784            us
# 3                 Comment créer son entreprise - IFJ  30484029            ch
# 4                                      French Berlin  27281862            de
#
#               Topic                                         event_name  \
# 0             [Wine                            Online Trivia via Zoom
# 1       [Innovation                            AMA with Agnes Misiurny
# ...

# %%
df_3.to_csv('meetup.csv')

# %%
df_3.to_excel('meetup.xlsx')

# %%
sqlEngine = create_engine('mysql+pymysql://root:Selin_1987@127.0.0.1/meetup', pool_recycle=3600)

dbConnection    = sqlEngine.connect()

# This is for creating data base
sqlEngine.execute("CREATE DATABASE IF NOT EXISTS MEETUP") #create db
sqlEngine.execute("USE MEETUP") # select new db

tableName   = "meetup"


try:
    frame = df_3.to_sql(tableName, dbConnection, if_exists='replace',index = False)

except ValueError as vx:
    print(vx)

except Exception as ex:   
    print(ex)

else:
    print("Table %s created successfully."%tableName);   

finally:
    dbConnection.close()
# Out:
# Table meetup created successfully.

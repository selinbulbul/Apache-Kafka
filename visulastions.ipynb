# %%
import pandas as pd
import seaborn as sb

# %%
df= pd.read_csv("rockset-meetup.csv")

# %%
df_json = pd.read_json('rockset.json')

# %%
df=

# %%
df
# Out:
#                                                   _meta  \
# 0     {"kafka":{"topic":"meetup","partition":0,"offs...
# 1     {"kafka":{"topic":"meetup","partition":0,"offs...
# 2     {"kafka":{"topic":"meetup","partition":0,"offs...
# 3     {"kafka":{"topic":"meetup","partition":0,"offs...
# 4     {"kafka":{"topic":"meetup","partition":0,"offs...
# ...                                                 ...
# 2000  {"kafka":{"topic":"meetup","partition":0,"offs...
# 2001  {"kafka":{"topic":"meetup","partition":0,"offs...
# 2002  {"kafka":{"topic":"meetup","partition":0,"offs...
# 2003  {"kafka":{"topic":"meetup","partition":0,"offs...
# 2004  {"kafka":{"topic":"meetup","partition":0,"offs...
#
#                                        _id  \
# 0     09c8d176-c6ec-784a-4ce4-1eea582b3b99
# 1     5dd83017-ca5d-654c-1f93-3e42ecc45184
# 2     258431f4-63c2-807a-7b8d-f4d9c2d3185e
# 3     be792538-1385-ec42-8917-ae31a1d55b5b
# 4     17c67ae4-f2a0-f58a-d84b-2196fdc243d6
# ...                                    ...
# 2000  998f5961-e59e-0eaa-2d6e-3848319d5981
# 2001  0d797c21-54df-a14e-9c31-f0503549aec0
# 2002  aee89c05-d14d-c9da-ec80-ce3f2031ea0c
# 2003  a4a1fbef-3be5-a2ac-0638-d83da7b81218
# 2004  7cc973b5-7910-8873-bf71-6ff0fbd5993d
#
#                                                   group  \
# 0     {"group_lat":-37.81,"group_name":"Northside Ex...
# 1     {"group_lat":-37.81,"group_name":"Product Talk...
# 2     {"group_lat":40.76,"group_name":"The Thalesian...
# 3     {"group_lat":46.52,"group_name":"Comment créer...
# 4     {"group_lat":52.52,"group_name":"French Berlin...
# ...                                                 ...
# 2000  {"group_lat":21.29,"group_name":"Oahu Long Ter...
# 2001  {"group_lat":47.38,"group_name":"ClickUp Geeks...
# 2002  {"group_lat":-33.87,"group_name":"Sydney UC - ...
# 2003  {"group_lat":40.42,"group_name":"Partidas de r...
# 2004  {"group_lat":48.14,"group_name":"Agile Heroes ...
#
#                                                   event response  \
# 0     {"event_name":"Online Trivia via Zoom ","time"...       no
# 1     {"event_name":"AMA with Agnes Misiurny","time"...      yes
# 2     {"event_name":"Webinar: Bilal Hafeez (Macro Hi...      yes
# 3     {"event_name":"L’amour du risque, oser malgré ...      yes
# 4     {"event_name":"Parlons français ! Café philoso...      yes
# ...                                                 ...      ...
# 2000  {"event_name":"Dinner at Mexico Restaurant","t...      yes
# 2001  {"event_name":"ClickUp «Docs» als Informations...      yes
# 2002  {"event_name":"Sydney UC August 2021 Meetup","...      yes
# 2003  {"event_name":"Aprende a Jugar a Fallout | One...      yes
# 2004  {"event_name":"„Facilitator - Funktionen und h...       no
#
#                       _event_time     rsvp_id  \
# 0     2021-08-19T07:42:48.406000Z  1883963961
# 1     2021-08-19T07:42:48.406000Z  1884076700
# 2     2021-08-19T07:42:48.406000Z  1884076873
# 3     2021-08-19T07:42:48.406000Z  1884076719
# 4     2021-08-19T07:42:48.406000Z  1884076769
# ...                           ...         ...
# 2000  2021-08-19T08:14:33.599000Z  1884078339
# 2001  2021-08-19T08:15:16.271000Z  1884078369
# 2002  2021-08-19T08:19:36.384000Z  1884078521
# 2003  2021-08-19T08:19:40.763000Z  1884078526
# 2004  2021-08-19T08:22:34.504000Z  1882048288
#
#                                                  member visibility  guests  \
# 0     {"member_id":286812947,"photo":"https://secure...     public       0
# 1     {"member_id":41344852,"photo":"https://secure....     public       0
# 2     {"member_id":305576915,"member_name":"Martin R...     public       0
# 3     {"member_id":35182672,"photo":"https://secure....     public       0
# 4     {"member_id":314005160,"photo":"https://secure...     public       0
# ...                                                 ...        ...     ...
# 2000  {"member_id":338740161,"photo":"https://secure...     public       0
# 2001  {"member_id":273053218,"photo":"https://secure...     public       0
# 2002  {"member_id":249093753,"photo":"https://secure...     public       0
# 2003  {"member_id":238092824,"member_name":"Borja Pr...     public       0
# 2004  {"member_id":337111790,"photo":"https://secure...     public       0
#
#               mtime                                              venue  \
# 0     1629358881316                                                NaN
# 1     1629358701725  {"venue_name":"Online event","lon":179.1962,"v...
# 2     1629358933752  {"venue_name":"Online event","lon":179.1962,"v...
# 3     1629358731000  {"venue_name":"Online event","lon":179.1962,"v...
# 4     1629358799000  {"venue_name":"B-Part am Gleisdreieck","lon":1...
# ...             ...                                                ...
# 2000  1629360873405  {"venue_name":"Mexico Restaurant","lon":-157.8...
# 2001  1629360916039  {"venue_name":"Online event","lon":179.1962,"v...
# 2002  1629361176125  {"venue_name":"Online event","lon":179.1962,"v...
# 2003  1629361180555  {"venue_name":"La Guarida del ContemplaRol","l...
# 2004  1629361354258  {"venue_name":"Online event","lon":179.1962,"v...
#
#       Unnamed: 12
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 2000          NaN
# 2001          NaN
# 2002          NaN
# 2003          NaN
# 2004          NaN
#
# [2005 rows x 13 columns]

# %%
df = df.drop(columns=["_meta", "_id", "Unnamed: 12"])

# %%
df
# Out:
#                                                   group  \
# 0     {"group_lat":-37.81,"group_name":"Northside Ex...
# 1     {"group_lat":-37.81,"group_name":"Product Talk...
# 2     {"group_lat":40.76,"group_name":"The Thalesian...
# 3     {"group_lat":46.52,"group_name":"Comment créer...
# 4     {"group_lat":52.52,"group_name":"French Berlin...
# ...                                                 ...
# 2000  {"group_lat":21.29,"group_name":"Oahu Long Ter...
# 2001  {"group_lat":47.38,"group_name":"ClickUp Geeks...
# 2002  {"group_lat":-33.87,"group_name":"Sydney UC - ...
# 2003  {"group_lat":40.42,"group_name":"Partidas de r...
# 2004  {"group_lat":48.14,"group_name":"Agile Heroes ...
#
#                                                   event response  \
# 0     {"event_name":"Online Trivia via Zoom ","time"...       no
# 1     {"event_name":"AMA with Agnes Misiurny","time"...      yes
# 2     {"event_name":"Webinar: Bilal Hafeez (Macro Hi...      yes
# 3     {"event_name":"L’amour du risque, oser malgré ...      yes
# 4     {"event_name":"Parlons français ! Café philoso...      yes
# ...                                                 ...      ...
# 2000  {"event_name":"Dinner at Mexico Restaurant","t...      yes
# 2001  {"event_name":"ClickUp «Docs» als Informations...      yes
# 2002  {"event_name":"Sydney UC August 2021 Meetup","...      yes
# 2003  {"event_name":"Aprende a Jugar a Fallout | One...      yes
# 2004  {"event_name":"„Facilitator - Funktionen und h...       no
#
#                       _event_time     rsvp_id  \
# 0     2021-08-19T07:42:48.406000Z  1883963961
# 1     2021-08-19T07:42:48.406000Z  1884076700
# 2     2021-08-19T07:42:48.406000Z  1884076873
# 3     2021-08-19T07:42:48.406000Z  1884076719
# 4     2021-08-19T07:42:48.406000Z  1884076769
# ...                           ...         ...
# 2000  2021-08-19T08:14:33.599000Z  1884078339
# 2001  2021-08-19T08:15:16.271000Z  1884078369
# 2002  2021-08-19T08:19:36.384000Z  1884078521
# 2003  2021-08-19T08:19:40.763000Z  1884078526
# 2004  2021-08-19T08:22:34.504000Z  1882048288
#
#                                                  member visibility  guests  \
# 0     {"member_id":286812947,"photo":"https://secure...     public       0
# 1     {"member_id":41344852,"photo":"https://secure....     public       0
# 2     {"member_id":305576915,"member_name":"Martin R...     public       0
# 3     {"member_id":35182672,"photo":"https://secure....     public       0
# 4     {"member_id":314005160,"photo":"https://secure...     public       0
# ...                                                 ...        ...     ...
# 2000  {"member_id":338740161,"photo":"https://secure...     public       0
# 2001  {"member_id":273053218,"photo":"https://secure...     public       0
# 2002  {"member_id":249093753,"photo":"https://secure...     public       0
# 2003  {"member_id":238092824,"member_name":"Borja Pr...     public       0
# 2004  {"member_id":337111790,"photo":"https://secure...     public       0
#
#               mtime                                              venue
# 0     1629358881316                                                NaN
# 1     1629358701725  {"venue_name":"Online event","lon":179.1962,"v...
# 2     1629358933752  {"venue_name":"Online event","lon":179.1962,"v...
# 3     1629358731000  {"venue_name":"Online event","lon":179.1962,"v...
# 4     1629358799000  {"venue_name":"B-Part am Gleisdreieck","lon":1...
# ...             ...                                                ...
# 2000  1629360873405  {"venue_name":"Mexico Restaurant","lon":-157.8...
# 2001  1629360916039  {"venue_name":"Online event","lon":179.1962,"v...
# 2002  1629361176125  {"venue_name":"Online event","lon":179.1962,"v...
# 2003  1629361180555  {"venue_name":"La Guarida del ContemplaRol","l...
# 2004  1629361354258  {"venue_name":"Online event","lon":179.1962,"v...
#
# [2005 rows x 10 columns]

# %%
df_1= pd.DataFrame(df.group.str.split(',').tolist())

# %%
df_1
# Out:
#                        0                                                  1   \
# 0     {"group_lat":-37.81  "group_name":"Northside Explorers (Thornbury/ ...
# 1     {"group_lat":-37.81             "group_name":"Product Talks Melbourne"
# 2      {"group_lat":40.76                      "group_name":"The Thalesians"
# 3      {"group_lat":46.52  "group_name":"Comment créer son entreprise - IFJ"
# 4      {"group_lat":52.52                       "group_name":"French Berlin"
# ...                   ...                                                ...
# 2000   {"group_lat":21.29  "group_name":"Oahu Long Term Residents and Loc...
# 2001   {"group_lat":47.38                "group_name":"ClickUp Geeks Zurich"
# 2002  {"group_lat":-33.87  "group_name":"Sydney UC - Microsoft Teams & Sk...
# 2003   {"group_lat":40.42  "group_name":"Partidas de rol en el ContemplaR...
# 2004   {"group_lat":48.14         "group_name":"Agile Heroes MeetUp München"
#
#                        2                                                  3   \
# 0     "group_id":23412765              "group_urlname":"Northside-Explorers"
# 1     "group_id":33585358          "group_urlname":"Product-Talks-Melbourne"
# 2      "group_id":1435784                       "group_urlname":"thalesians"
# 3     "group_id":30484029            "group_urlname":"creationentrepriseIFJ"
# 4     "group_id":27281862                     "group_urlname":"FrenchBerlin"
# ...                   ...                                                ...
# 2000  "group_id":35305700  "group_urlname":"oahu-residents-and-locals-mee...
# 2001  "group_id":34727848             "group_urlname":"clickup-geeks-zurich"
# 2002  "group_id":17524012                        "group_urlname":"Sydney-UC"
# 2003  "group_id":27954497                     "group_urlname":"contemplarol"
# 2004  "group_id":33917975      "group_urlname":"Agile-Heroes-MeetUp-Munchen"
#
#                         4                                                  5   \
# 0     "group_country":"au"               "group_topics":[{"topic_name":"Wine"
# 1     "group_country":"au"         "group_topics":[{"topic_name":"Innovation"
# 2     "group_country":"us"                                 "group_state":"NY"
# 3     "group_country":"ch"     "group_topics":[{"topic_name":"Small Business"
# 4     "group_country":"de"    "group_topics":[{"topic_name":"French Language"
# ...                    ...                                                ...
# 2000  "group_country":"us"                                 "group_state":"HI"
# 2001  "group_country":"ch"  "group_topics":[{"topic_name":"Personal Develo...
# 2002  "group_country":"au"         "group_topics":[{"topic_name":"Office 365"
# 2003  "group_country":"es"  "group_topics":[{"topic_name":"Role-Playing Ga...
# 2004  "group_country":"de"              "group_topics":[{"topic_name":"Scrum"
#
#                                                      6   \
# 0                                      "urlkey":"wine"}
# 1                                "urlkey":"innovation"}
# 2     "group_topics":[{"topic_name":"Financial Engin...
# 3                                  "urlkey":"smallbiz"}
# 4                                    "urlkey":"french"}
# ...                                                 ...
# 2000             "group_topics":[{"topic_name":"Hiking"
# 2001                   "urlkey":"personal-development"}
# 2002                             "urlkey":"office-365"}
# 2003                "urlkey":"role-playing-games-rpgs"}
# 2004                                  "urlkey":"scrum"}
#
#                                                      7   \
# 0                      {"topic_name":"Local Activities"
# 1                        {"topic_name":"Product Design"
# 2                              "urlkey":"financialeng"}
# 3                              {"topic_name":"Business"
# 4                       {"topic_name":"French Students"
# ...                                                 ...
# 2000                                 "urlkey":"hiking"}
# 2001                  {"topic_name":"PMP Certification"
# 2002  {"topic_name":"Internet Communication Technology"
# 2003     {"topic_name":"Iniciación a los juegos de rol"
# 2004           {"topic_name":"Agile Project Management"
#
#                                               8   \
# 0                   "urlkey":"local-activities"}
# 1                      "urlkey":"productdesign"}
# 2                    {"topic_name":"Mathematics"
# 3                           "urlkey":"business"}
# 4                    "urlkey":"french-students"}
# ...                                          ...
# 2000                  {"topic_name":"Dining Out"
# 2001               "urlkey":"pmp-certification"}
# 2002                         "urlkey":"webcomm"}
# 2003  "urlkey":"iniciacion-a-los-juegos-de-rol"}
# 2004        "urlkey":"agile-project-management"}
#
#                                                      9   ...    41    42  \
# 0                            {"topic_name":"Dining Out"  ...  None  None
# 1              {"topic_name":"Professional Development"  ...  None  None
# 2                               "urlkey":"mathematics"}  ...  None  None
# 3               {"topic_name":"Professional Networking"  ...  None  None
# 4     {"topic_name":"French Speakers; French Convers...  ...  None  None
# ...                                                 ...  ...   ...   ...
# 2000                              "urlkey":"diningout"}  ...  None  None
# 2001                   {"topic_name":"Entrepreneurship"  ...  None  None
# 2002                          {"topic_name":"Microsoft"  ...  None  None
# 2003  {"topic_name":"Tabletop Role Playing and Board...  ...  None  None
# 2004                             {"topic_name":"Kanban"  ...  None  None
#
#         43    44    45    46    47    48    49    50
# 0     None  None  None  None  None  None  None  None
# 1     None  None  None  None  None  None  None  None
# 2     None  None  None  None  None  None  None  None
# 3     None  None  None  None  None  None  None  None
# 4     None  None  None  None  None  None  None  None
# ...    ...   ...   ...   ...   ...   ...   ...   ...
# 2000  None  None  None  None  None  None  None  None
# 2001  None  None  None  None  None  None  None  None
# 2002  None  None  None  None  None  None  None  None
# 2003  None  None  None  None  None  None  None  None
# 2004  None  None  None  None  None  None  None  None
#
# [2005 rows x 51 columns]

# %%
df_1 = df_1.dropna(axis=1)

# %%
df_1
# Out:
#                         0                                                  1  \
# 0     {"group_lat":-37.81  "group_name":"Northside Explorers (Thornbury/ ...
# 1     {"group_lat":-37.81             "group_name":"Product Talks Melbourne"
# 2      {"group_lat":40.76                      "group_name":"The Thalesians"
# 3      {"group_lat":46.52  "group_name":"Comment créer son entreprise - IFJ"
# 4      {"group_lat":52.52                       "group_name":"French Berlin"
# ...                   ...                                                ...
# 2000   {"group_lat":21.29  "group_name":"Oahu Long Term Residents and Loc...
# 2001   {"group_lat":47.38                "group_name":"ClickUp Geeks Zurich"
# 2002  {"group_lat":-33.87  "group_name":"Sydney UC - Microsoft Teams & Sk...
# 2003   {"group_lat":40.42  "group_name":"Partidas de rol en el ContemplaR...
# 2004   {"group_lat":48.14         "group_name":"Agile Heroes MeetUp München"
#
#                         2                                                  3  \
# 0     "group_id":23412765              "group_urlname":"Northside-Explorers"
# 1     "group_id":33585358          "group_urlname":"Product-Talks-Melbourne"
# 2      "group_id":1435784                       "group_urlname":"thalesians"
# 3     "group_id":30484029            "group_urlname":"creationentrepriseIFJ"
# 4     "group_id":27281862                     "group_urlname":"FrenchBerlin"
# ...                   ...                                                ...
# 2000  "group_id":35305700  "group_urlname":"oahu-residents-and-locals-mee...
# 2001  "group_id":34727848             "group_urlname":"clickup-geeks-zurich"
# 2002  "group_id":17524012                        "group_urlname":"Sydney-UC"
# 2003  "group_id":27954497                     "group_urlname":"contemplarol"
# 2004  "group_id":33917975      "group_urlname":"Agile-Heroes-MeetUp-Munchen"
#
#                          4                                                  5  \
# 0     "group_country":"au"               "group_topics":[{"topic_name":"Wine"
# 1     "group_country":"au"         "group_topics":[{"topic_name":"Innovation"
# 2     "group_country":"us"                                 "group_state":"NY"
# 3     "group_country":"ch"     "group_topics":[{"topic_name":"Small Business"
# 4     "group_country":"de"    "group_topics":[{"topic_name":"French Language"
# ...                    ...                                                ...
# 2000  "group_country":"us"                                 "group_state":"HI"
# 2001  "group_country":"ch"  "group_topics":[{"topic_name":"Personal Develo...
# 2002  "group_country":"au"         "group_topics":[{"topic_name":"Office 365"
# 2003  "group_country":"es"  "group_topics":[{"topic_name":"Role-Playing Ga...
# 2004  "group_country":"de"              "group_topics":[{"topic_name":"Scrum"
#
#                                                       6  \
# 0                                      "urlkey":"wine"}
# 1                                "urlkey":"innovation"}
# 2     "group_topics":[{"topic_name":"Financial Engin...
# 3                                  "urlkey":"smallbiz"}
# 4                                    "urlkey":"french"}
# ...                                                 ...
# 2000             "group_topics":[{"topic_name":"Hiking"
# 2001                   "urlkey":"personal-development"}
# 2002                             "urlkey":"office-365"}
# 2003                "urlkey":"role-playing-games-rpgs"}
# 2004                                  "urlkey":"scrum"}
#
#                                                       7  \
# 0                      {"topic_name":"Local Activities"
# 1                        {"topic_name":"Product Design"
# 2                              "urlkey":"financialeng"}
# 3                              {"topic_name":"Business"
# 4                       {"topic_name":"French Students"
# ...                                                 ...
# 2000                                 "urlkey":"hiking"}
# 2001                  {"topic_name":"PMP Certification"
# 2002  {"topic_name":"Internet Communication Technology"
# 2003     {"topic_name":"Iniciación a los juegos de rol"
# 2004           {"topic_name":"Agile Project Management"
#
#                                                8
# 0                   "urlkey":"local-activities"}
# 1                      "urlkey":"productdesign"}
# 2                    {"topic_name":"Mathematics"
# 3                           "urlkey":"business"}
# 4                    "urlkey":"french-students"}
# ...                                          ...
# 2000                  {"topic_name":"Dining Out"
# 2001               "urlkey":"pmp-certification"}
# 2002                         "urlkey":"webcomm"}
# 2003  "urlkey":"iniciacion-a-los-juegos-de-rol"}
# 2004        "urlkey":"agile-project-management"}
#
# [2005 rows x 9 columns]

# %%
df_1 = df.group.str.split(",",expand=True)

# %%
df_1
# Out:
#                        0                                                  1   \
# 0     {"group_lat":-37.81  "group_name":"Northside Explorers (Thornbury/ ...
# 1     {"group_lat":-37.81             "group_name":"Product Talks Melbourne"
# 2      {"group_lat":40.76                      "group_name":"The Thalesians"
# 3      {"group_lat":46.52  "group_name":"Comment créer son entreprise - IFJ"
# 4      {"group_lat":52.52                       "group_name":"French Berlin"
# ...                   ...                                                ...
# 2000   {"group_lat":21.29  "group_name":"Oahu Long Term Residents and Loc...
# 2001   {"group_lat":47.38                "group_name":"ClickUp Geeks Zurich"
# 2002  {"group_lat":-33.87  "group_name":"Sydney UC - Microsoft Teams & Sk...
# 2003   {"group_lat":40.42  "group_name":"Partidas de rol en el ContemplaR...
# 2004   {"group_lat":48.14         "group_name":"Agile Heroes MeetUp München"
#
#                        2                                                  3   \
# 0     "group_id":23412765              "group_urlname":"Northside-Explorers"
# 1     "group_id":33585358          "group_urlname":"Product-Talks-Melbourne"
# 2      "group_id":1435784                       "group_urlname":"thalesians"
# 3     "group_id":30484029            "group_urlname":"creationentrepriseIFJ"
# 4     "group_id":27281862                     "group_urlname":"FrenchBerlin"
# ...                   ...                                                ...
# 2000  "group_id":35305700  "group_urlname":"oahu-residents-and-locals-mee...
# 2001  "group_id":34727848             "group_urlname":"clickup-geeks-zurich"
# 2002  "group_id":17524012                        "group_urlname":"Sydney-UC"
# 2003  "group_id":27954497                     "group_urlname":"contemplarol"
# 2004  "group_id":33917975      "group_urlname":"Agile-Heroes-MeetUp-Munchen"
#
#                         4                                                  5   \
# 0     "group_country":"au"               "group_topics":[{"topic_name":"Wine"
# 1     "group_country":"au"         "group_topics":[{"topic_name":"Innovation"
# 2     "group_country":"us"                                 "group_state":"NY"
# 3     "group_country":"ch"     "group_topics":[{"topic_name":"Small Business"
# 4     "group_country":"de"    "group_topics":[{"topic_name":"French Language"
# ...                    ...                                                ...
# 2000  "group_country":"us"                                 "group_state":"HI"
# 2001  "group_country":"ch"  "group_topics":[{"topic_name":"Personal Develo...
# 2002  "group_country":"au"         "group_topics":[{"topic_name":"Office 365"
# 2003  "group_country":"es"  "group_topics":[{"topic_name":"Role-Playing Ga...
# 2004  "group_country":"de"              "group_topics":[{"topic_name":"Scrum"
#
#                                                      6   \
# 0                                      "urlkey":"wine"}
# 1                                "urlkey":"innovation"}
# 2     "group_topics":[{"topic_name":"Financial Engin...
# 3                                  "urlkey":"smallbiz"}
# 4                                    "urlkey":"french"}
# ...                                                 ...
# 2000             "group_topics":[{"topic_name":"Hiking"
# 2001                   "urlkey":"personal-development"}
# 2002                             "urlkey":"office-365"}
# 2003                "urlkey":"role-playing-games-rpgs"}
# 2004                                  "urlkey":"scrum"}
#
#                                                      7   \
# 0                      {"topic_name":"Local Activities"
# 1                        {"topic_name":"Product Design"
# 2                              "urlkey":"financialeng"}
# 3                              {"topic_name":"Business"
# 4                       {"topic_name":"French Students"
# ...                                                 ...
# 2000                                 "urlkey":"hiking"}
# 2001                  {"topic_name":"PMP Certification"
# 2002  {"topic_name":"Internet Communication Technology"
# 2003     {"topic_name":"Iniciación a los juegos de rol"
# 2004           {"topic_name":"Agile Project Management"
#
#                                               8   \
# 0                   "urlkey":"local-activities"}
# 1                      "urlkey":"productdesign"}
# 2                    {"topic_name":"Mathematics"
# 3                           "urlkey":"business"}
# 4                    "urlkey":"french-students"}
# ...                                          ...
# 2000                  {"topic_name":"Dining Out"
# 2001               "urlkey":"pmp-certification"}
# 2002                         "urlkey":"webcomm"}
# 2003  "urlkey":"iniciacion-a-los-juegos-de-rol"}
# 2004        "urlkey":"agile-project-management"}
#
#                                                      9   ...    41    42  \
# 0                            {"topic_name":"Dining Out"  ...  None  None
# 1              {"topic_name":"Professional Development"  ...  None  None
# 2                               "urlkey":"mathematics"}  ...  None  None
# 3               {"topic_name":"Professional Networking"  ...  None  None
# 4     {"topic_name":"French Speakers; French Convers...  ...  None  None
# ...                                                 ...  ...   ...   ...
# 2000                              "urlkey":"diningout"}  ...  None  None
# 2001                   {"topic_name":"Entrepreneurship"  ...  None  None
# 2002                          {"topic_name":"Microsoft"  ...  None  None
# 2003  {"topic_name":"Tabletop Role Playing and Board...  ...  None  None
# 2004                             {"topic_name":"Kanban"  ...  None  None
#
#         43    44    45    46    47    48    49    50
# 0     None  None  None  None  None  None  None  None
# 1     None  None  None  None  None  None  None  None
# 2     None  None  None  None  None  None  None  None
# 3     None  None  None  None  None  None  None  None
# 4     None  None  None  None  None  None  None  None
# ...    ...   ...   ...   ...   ...   ...   ...   ...
# 2000  None  None  None  None  None  None  None  None
# 2001  None  None  None  None  None  None  None  None
# 2002  None  None  None  None  None  None  None  None
# 2003  None  None  None  None  None  None  None  None
# 2004  None  None  None  None  None  None  None  None
#
# [2005 rows x 51 columns]

# %%
df_1 = df.group.str.split("_",expand=True)

# %%
df_1
# Out:
#            0                   1   \
# 0     {"group  lat":-37.81,"group
# 1     {"group  lat":-37.81,"group
# 2     {"group   lat":40.76,"group
# 3     {"group   lat":46.52,"group
# 4     {"group   lat":52.52,"group
# ...       ...                 ...
# 2000  {"group   lat":21.29,"group
# 2001  {"group   lat":47.38,"group
# 2002  {"group  lat":-33.87,"group
# 2003  {"group   lat":40.42,"group
# 2004  {"group   lat":48.14,"group
#
#                                                      2                    3   \
# 0     name":"Northside Explorers (Thornbury/ Northco...  id":23412765,"group
# 1                name":"Product Talks Melbourne","group  id":33585358,"group
# 2                         name":"The Thalesians","group   id":1435784,"group
# 3     name":"Comment créer son entreprise - IFJ","group  id":30484029,"group
# 4                          name":"French Berlin","group  id":27281862,"group
# ...                                                 ...                  ...
# 2000  name":"Oahu Long Term Residents and Locals Mee...  id":35305700,"group
# 2001                name":"ClickUp Geeks Zurich","group  id":34727848,"group
# 2002  name":"Sydney UC - Microsoft Teams & Skype for...  id":17524012,"group
# 2003  name":"Partidas de rol en el ContemplaRol (onl...  id":27954497,"group
# 2004         name":"Agile Heroes MeetUp München","group  id":33917975,"group
#
#                                                      4                     5   \
# 0                 urlname":"Northside-Explorers","group  country":"au","group
# 1             urlname":"Product-Talks-Melbourne","group  country":"au","group
# 2                          urlname":"thalesians","group  country":"us","group
# 3               urlname":"creationentrepriseIFJ","group  country":"ch","group
# 4                        urlname":"FrenchBerlin","group  country":"de","group
# ...                                                 ...                   ...
# 2000  urlname":"oahu-residents-and-locals-meetup-gro...  country":"us","group
# 2001             urlname":"clickup-geeks-zurich","group  country":"ch","group
# 2002                        urlname":"Sydney-UC","group  country":"au","group
# 2003                     urlname":"contemplarol","group  country":"es","group
# 2004      urlname":"Agile-Heroes-MeetUp-Munchen","group  country":"de","group
#
#                       6                                                  7   \
# 0       topics":[{"topic              name":"Wine","urlkey":"wine"},{"topic
# 1       topics":[{"topic  name":"Innovation","urlkey":"innovation"},{"topic
# 2     state":"NY","group                                   topics":[{"topic
# 3       topics":[{"topic  name":"Small Business","urlkey":"smallbiz"},{"...
# 4       topics":[{"topic  name":"French Language","urlkey":"french"},{"t...
# ...                  ...                                                ...
# 2000  state":"HI","group                                   topics":[{"topic
# 2001    topics":[{"topic  name":"Personal Development","urlkey":"persona...
# 2002    topics":[{"topic  name":"Office 365","urlkey":"office-365"},{"topic
# 2003    topics":[{"topic  name":"Role-Playing Games","urlkey":"role-play...
# 2004    topics":[{"topic            name":"Scrum","urlkey":"scrum"},{"topic
#
#                                                      8   \
# 0     name":"Local Activities","urlkey":"local-activ...
# 1     name":"Product Design","urlkey":"productdesign...
# 2     name":"Financial Engineering","urlkey":"financ...
# 3         name":"Business","urlkey":"business"},{"topic
# 4     name":"French Students","urlkey":"french-stude...
# ...                                                 ...
# 2000          name":"Hiking","urlkey":"hiking"},{"topic
# 2001  name":"PMP Certification","urlkey":"pmp-certif...
# 2002  name":"Internet Communication Technology","url...
# 2003  name":"Iniciación a los juegos de rol","urlkey...
# 2004  name":"Agile Project Management","urlkey":"agi...
#
#                                                      9   ...  \
# 0      name":"Dining Out","urlkey":"diningout"},{"topic  ...
# 1     name":"Professional Development","urlkey":"pro...  ...
# 2     name":"Mathematics","urlkey":"mathematics"},{"...  ...
# 3     name":"Professional Networking","urlkey":"prof...  ...
# 4     name":"French Speakers; French Conversation;",...  ...
# ...                                                 ...  ...
# 2000   name":"Dining Out","urlkey":"diningout"},{"topic  ...
# 2001  name":"Entrepreneurship","urlkey":"entrepreneu...  ...
# 2002     name":"Microsoft","urlkey":"microsft"},{"topic  ...
# 2003  name":"Tabletop Role Playing and Board Games",...  ...
# 2004          name":"Kanban","urlkey":"kanban"},{"topic  ...
#
#                                                      18  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3     name":"How to Start Your Own Business","urlkey...
# 4     name":"International Friends","urlkey":"intern...
# ...                                                 ...
# 2000                            city":"Honolulu","group
# 2001                                               None
# 2002  name":"Unified Communications","urlkey":"unifi...
# 2003            name":"Games","urlkey":"games"},{"topic
# 2004                                               None
#
#                                                      19  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3     name":"How to start a business","urlkey":"how-...
# 4     name":"French Language Lovers; French Language...
# ...                                                 ...
# 2000                                       lon":-157.8}
# 2001                                               None
# 2002  name":"Unified Messaging","urlkey":"unified-me...
# 2003  name":"Juegos de rol online","urlkey":"juegos-...
# 2004                                               None
#
#                                                      20  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3     name":"Thinking of Starting Your Own Company",...
# 4     name":"French conversation and French culture"...
# ...                                                 ...
# 2000                                               None
# 2001                                               None
# 2002  name":"Microsoft Lync","urlkey":"microsoft-lyn...
# 2003  name":"Strategy Games","urlkey":"strategy-game...
# 2004                                               None
#
#                                                      21  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3           name":"Company","urlkey":"company"}],"group
# 4                                 city":"Berlin","group
# ...                                                 ...
# 2000                                               None
# 2001                                               None
# 2002  name":"Lync Online","urlkey":"lync-online"}],"...
# 2003  name":"Board Games","urlkey":"board-games"}],"...
# 2004                                               None
#
#                            22            23    24    25    26    27
# 0                        None          None  None  None  None  None
# 1                        None          None  None  None  None  None
# 2                        None          None  None  None  None  None
# 3     city":"Lausanne","group    lon":6.62}  None  None  None  None
# 4                 lon":13.38}          None  None  None  None  None
# ...                       ...           ...   ...   ...   ...   ...
# 2000                     None          None  None  None  None  None
# 2001                     None          None  None  None  None  None
# 2002    city":"Sydney","group  lon":151.21}  None  None  None  None
# 2003    city":"Madrid","group   lon":-3.71}  None  None  None  None
# 2004                     None          None  None  None  None  None
#
# [2005 rows x 28 columns]

# %%
df_1 = df_1.dropna(axis=1)

# %%
df_1
# Out:
#             0                   1  \
# 0     {"group  lat":-37.81,"group
# 1     {"group  lat":-37.81,"group
# 2     {"group   lat":40.76,"group
# 3     {"group   lat":46.52,"group
# 4     {"group   lat":52.52,"group
# ...       ...                 ...
# 2000  {"group   lat":21.29,"group
# 2001  {"group   lat":47.38,"group
# 2002  {"group  lat":-33.87,"group
# 2003  {"group   lat":40.42,"group
# 2004  {"group   lat":48.14,"group
#
#                                                       2                    3  \
# 0     name":"Northside Explorers (Thornbury/ Northco...  id":23412765,"group
# 1                name":"Product Talks Melbourne","group  id":33585358,"group
# 2                         name":"The Thalesians","group   id":1435784,"group
# 3     name":"Comment créer son entreprise - IFJ","group  id":30484029,"group
# 4                          name":"French Berlin","group  id":27281862,"group
# ...                                                 ...                  ...
# 2000  name":"Oahu Long Term Residents and Locals Mee...  id":35305700,"group
# 2001                name":"ClickUp Geeks Zurich","group  id":34727848,"group
# 2002  name":"Sydney UC - Microsoft Teams & Skype for...  id":17524012,"group
# 2003  name":"Partidas de rol en el ContemplaRol (onl...  id":27954497,"group
# 2004         name":"Agile Heroes MeetUp München","group  id":33917975,"group
#
#                                                       4                     5  \
# 0                 urlname":"Northside-Explorers","group  country":"au","group
# 1             urlname":"Product-Talks-Melbourne","group  country":"au","group
# 2                          urlname":"thalesians","group  country":"us","group
# 3               urlname":"creationentrepriseIFJ","group  country":"ch","group
# 4                        urlname":"FrenchBerlin","group  country":"de","group
# ...                                                 ...                   ...
# 2000  urlname":"oahu-residents-and-locals-meetup-gro...  country":"us","group
# 2001             urlname":"clickup-geeks-zurich","group  country":"ch","group
# 2002                        urlname":"Sydney-UC","group  country":"au","group
# 2003                     urlname":"contemplarol","group  country":"es","group
# 2004      urlname":"Agile-Heroes-MeetUp-Munchen","group  country":"de","group
#
#                        6                                                  7  \
# 0       topics":[{"topic              name":"Wine","urlkey":"wine"},{"topic
# 1       topics":[{"topic  name":"Innovation","urlkey":"innovation"},{"topic
# 2     state":"NY","group                                   topics":[{"topic
# 3       topics":[{"topic  name":"Small Business","urlkey":"smallbiz"},{"...
# 4       topics":[{"topic  name":"French Language","urlkey":"french"},{"t...
# ...                  ...                                                ...
# 2000  state":"HI","group                                   topics":[{"topic
# 2001    topics":[{"topic  name":"Personal Development","urlkey":"persona...
# 2002    topics":[{"topic  name":"Office 365","urlkey":"office-365"},{"topic
# 2003    topics":[{"topic  name":"Role-Playing Games","urlkey":"role-play...
# 2004    topics":[{"topic            name":"Scrum","urlkey":"scrum"},{"topic
#
#                                                       8  \
# 0     name":"Local Activities","urlkey":"local-activ...
# 1     name":"Product Design","urlkey":"productdesign...
# 2     name":"Financial Engineering","urlkey":"financ...
# 3         name":"Business","urlkey":"business"},{"topic
# 4     name":"French Students","urlkey":"french-stude...
# ...                                                 ...
# 2000          name":"Hiking","urlkey":"hiking"},{"topic
# 2001  name":"PMP Certification","urlkey":"pmp-certif...
# 2002  name":"Internet Communication Technology","url...
# 2003  name":"Iniciación a los juegos de rol","urlkey...
# 2004  name":"Agile Project Management","urlkey":"agi...
#
#                                                       9
# 0      name":"Dining Out","urlkey":"diningout"},{"topic
# 1     name":"Professional Development","urlkey":"pro...
# 2     name":"Mathematics","urlkey":"mathematics"},{"...
# 3     name":"Professional Networking","urlkey":"prof...
# 4     name":"French Speakers; French Conversation;",...
# ...                                                 ...
# 2000   name":"Dining Out","urlkey":"diningout"},{"topic
# 2001  name":"Entrepreneurship","urlkey":"entrepreneu...
# 2002     name":"Microsoft","urlkey":"microsft"},{"topic
# 2003  name":"Tabletop Role Playing and Board Games",...
# 2004          name":"Kanban","urlkey":"kanban"},{"topic
#
# [2005 rows x 10 columns]

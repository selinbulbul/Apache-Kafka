# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np

# %%
df= pd.read_csv("meetup.csv")

# %%
df.head(2)
# Out:
#    Unnamed: 0 response     rsvp_id visibility  guests  \
# 0           0       no  1883963961     public       0
# 1           1      yes  1884076700     public       0
#
#                                           Group_name  Group_ID Group_Country  \
# 0  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765            au
# 1                            Product Talks Melbourne  33585358            au
#
#          Topic               event_name  \
# 0        [Wine  Online Trivia via Zoom
# 1  [Innovation  AMA with Agnes Misiurny
#
#                                            event_url  member_id  \
# 0  https://www.meetup.com/Northside-Explorers/eve...  286812947
# 1  https://www.meetup.com/Product-Talks-Melbourne...   41344852
#
#                                         member_photo  member_name  event_date  \
# 0  https://secure.meetupstatic.com/photos/member/...       Eilish  2021-08-19
# 1  https://secure.meetupstatic.com/photos/member/...  Luke Kenyon  2021-08-19
#
#   event_time
# 0   07:42:48
# 1   07:42:48

# %%
df = df.drop (columns = "Unnamed: 0")

# %%
df.head(2)
# Out:
#   response     rsvp_id visibility  guests  \
# 0       no  1883963961     public       0
# 1      yes  1884076700     public       0
#
#                                           Group_name  Group_ID Group_Country  \
# 0  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765            au
# 1                            Product Talks Melbourne  33585358            au
#
#          Topic               event_name  \
# 0        [Wine  Online Trivia via Zoom
# 1  [Innovation  AMA with Agnes Misiurny
#
#                                            event_url  member_id  \
# 0  https://www.meetup.com/Northside-Explorers/eve...  286812947
# 1  https://www.meetup.com/Product-Talks-Melbourne...   41344852
#
#                                         member_photo  member_name  event_date  \
# 0  https://secure.meetupstatic.com/photos/member/...       Eilish  2021-08-19
# 1  https://secure.meetupstatic.com/photos/member/...  Luke Kenyon  2021-08-19
#
#   event_time
# 0   07:42:48
# 1   07:42:48

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2005 entries, 0 to 2004
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   response       2005 non-null   object
#  1   rsvp_id        2005 non-null   int64
#  2   visibility     2005 non-null   object
#  3   guests         2005 non-null   int64
#  4   Group_name     2005 non-null   object
#  5   Group_ID       2005 non-null   object
#  6   Group_Country  2005 non-null   object
#  7   Topic          2005 non-null   object
#  8   event_name     2005 non-null   object
#  9   event_url      2005 non-null   object
#  10  member_id      2005 non-null   object
#  11  member_photo   2005 non-null   object
#  12  member_name    1825 non-null   object
#  13  event_date     2005 non-null   object
#  14  event_time     2005 non-null   object
# dtypes: int64(2), object(13)
# memory usage: 235.1+ KB

# %%
df["event_date"]= pd.to_datetime(df["event_date"])

# %%
df['event_month'] = pd.to_datetime(df['event_date'], format='%Y-%m-%d').dt.strftime('%Y-%m')

# %%
df.head()
# Out:
#   response     rsvp_id visibility  guests  \
# 0       no  1883963961     public       0
# 1      yes  1884076700     public       0
# 2      yes  1884076873     public       0
# 3      yes  1884076719     public       0
# 4      yes  1884076769     public       0
#
#                                           Group_name  Group_ID Group_Country  \
# 0  Northside Explorers (Thornbury/ Northcote/ Fit...  23412765            au
# 1                            Product Talks Melbourne  33585358            au
# 2                                     The Thalesians   1435784            us
# 3                 Comment créer son entreprise - IFJ  30484029            ch
# 4                                      French Berlin  27281862            de
#
#               Topic                                         event_name  \
# 0             [Wine                            Online Trivia via Zoom
# 1       [Innovation                            AMA with Agnes Misiurny
# 2     group_stateNY  Webinar: Bilal Hafeez (Macro Hive): How Macro ...
# 3   [Small Business                                  L’amour du risque
# 4  [French Language    Parlons français ! Café philosophie & politique
#
#                                            event_url  member_id  \
# 0  https://www.meetup.com/Northside-Explorers/eve...  286812947
# 1  https://www.meetup.com/Product-Talks-Melbourne...   41344852
# 2  https://www.meetup.com/thalesians/events/28019...  305576915
# 3                               "time":1632846600000   35182672
# 4  https://www.meetup.com/FrenchBerlin/events/280...  314005160
#
#                                         member_photo  member_name event_date  \
# 0  https://secure.meetupstatic.com/photos/member/...       Eilish 2021-08-19
# 1  https://secure.meetupstatic.com/photos/member/...  Luke Kenyon 2021-08-19
# 2                    "member_name":"Martin Richter"}          NaN 2021-08-19
# 3  https://secure.meetupstatic.com/photos/member/...        Clare 2021-08-19
# 4  https://secure.meetupstatic.com/photos/member/...        Olena 2021-08-19
#
#   event_time event_month
# 0   07:42:48     2021-08
# 1   07:42:48     2021-08
# 2   07:42:48     2021-08
# 3   07:42:48     2021-08
# 4   07:42:48     2021-08

# %%
df["Group_Country"].value_counts()
# Out:
# gb                                              333
# us                                              333
# au                                              184
# de                                              133
# group_id:33276575                               112
#                                                ...
# mu                                                1
# group_urlname:Southington-Area-Movies-Meetup      1
# group_urlname:CordyKet                            1
# rs                                                1
# group_id:35200919                                 1
# Name: Group_Country, Length: 118, dtype: int64
